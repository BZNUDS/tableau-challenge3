# %%
import pandas as pd
import glob
import os

# setting the path for joining multiple files
# files = os.path.join("C:\\Users\\amit_\\Desktop\\", "sales*.csv")
# files = os.path.join("C:\\Users\\BZ Northwestern BC\\Class\\Tableau-Challenge\\", "20211*.csv") 
files = os.path.join("C:\\Users\\BZ Northwestern BC\\Class\\Tableau-Challenge\\Key_12_Month_citibike-tripdata\\", "*citibike-tripdata*.csv") 


# list of merged files returned
files = glob.glob(files)

print("Resultant CSV after joining all CSV files at a particular location...");

# joining files with concat and read_csv
df = pd.concat(map(pd.read_csv, files), ignore_index=True)
df.to_csv('out.csv',index=False)
print("df.head()");
df.head()

# %%
df

# %%
df.to_csv('out.csv',index=False)
print("df.head()");
df.head()

# %%
df

# %%
import pandas as pd
import glob
import os

# setting the path for joining multiple files
# files = os.path.join("C:\\Users\\amit_\\Desktop\\", "sales*.csv")
# files = os.path.join("C:\\Users\\BZ Northwestern BC\\Class\\Tableau-Challenge\\", "20211*.csv") 
files = os.path.join("C:\\Users\\BZ Northwestern BC\\Class\\Tableau-Challenge\\Key_12_Month_citibike-tripdata\\", "*citibike-tripdata*.csv") 


# list of merged files returned
files = glob.glob(files)

print("Resultant CSV after joining all CSV files at a particular location...");

# joining files with concat and read_csv
df2 = pd.concat(map(pd.read_csv, files), ignore_index=True)
print("Did Concat")
df2.to_csv('out2.csv',index=False)
print("df2.head()");
df2

# %%
    for row in df2:
            print(row)

# %%
df2[18816537:18817537]

# %%
import pandas as pd
import glob
import os

# setting the path for joining multiple files
# files = os.path.join("C:\\Users\\amit_\\Desktop\\", "sales*.csv")
# files = os.path.join("C:\\Users\\BZ Northwestern BC\\Class\\Tableau-Challenge\\", "20211*.csv") 
files = os.path.join("C:\\Users\\BZ Northwestern BC\\Class\\Tableau-Challenge\\Key_4_Month_citibike-tripdata\\", "*citibike-tripdata*.csv") 


# list of merged files returned
files = glob.glob(files)

print("Resultant CSV after joining all CSV files at a particular location...");

# joining files with concat and read_csv
df3 = pd.concat(map(pd.read_csv, files), ignore_index=True)
print("Did Concat")
df3.to_csv('out3.csv',index=False)
print("Printing df3.head()");
df3
# Out:
# Resultant CSV after joining all CSV files at a particular location...
# C:\Users\BZ Northwestern BC\anaconda3\lib\site-packages\pandas\core\reshape\concat.py:294: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   op = _Concatenator(
# Did Concat
# df3.head()
#                   ride_id  rideable_type           started_at  \
# 0        55262E4365A955A2   classic_bike  2022-01-18 08:23:52
# 1        D272F1B15D841EC0   classic_bike  2022-01-21 09:03:22
# 2        D1FCEF55EB4A807F   classic_bike  2022-01-22 14:28:32
# 3        E9CBDC6A0162C068  electric_bike  2022-01-19 14:49:47
# 4        2177A5B57326CE9B  electric_bike  2022-01-16 14:36:06
# ...                   ...            ...                  ...
# 6499184  5EBE9D296B9D3E3C   classic_bike  2022-04-22 13:08:15
# 6499185  B66382DEDA84C464   classic_bike  2022-04-13 17:10:49
# 6499186  9EC4C49BE4CB1A09   classic_bike  2022-04-12 15:58:47
# ...

# %%
import pandas as pd
import glob
import os

# setting the path for joining multiple files
# files = os.path.join("C:\\Users\\amit_\\Desktop\\", "sales*.csv")
# files = os.path.join("C:\\Users\\BZ Northwestern BC\\Class\\Tableau-Challenge\\", "20211*.csv") 
files = os.path.join("C:\\Users\\BZ Northwestern BC\\Class\\Tableau-Challenge\\Key_4_Month_citibike-tripdata\\", "*citibike-tripdata*.csv") 


# list of merged files returned
files = glob.glob(files)

print("Resultant CSV after joining all CSV files at a particular location...");

# joining files with concat and read_csv
df3 = pd.concat(map(pd.read_csv, files), ignore_index=True)
print("Did Concat")
df3.to_csv('out3.csv',index=False)
print("Printing df3.head()");
df3
# Out:
# Resultant CSV after joining all CSV files at a particular location...
# C:\Users\BZ Northwestern BC\anaconda3\lib\site-packages\pandas\core\reshape\concat.py:294: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   op = _Concatenator(
# Did Concat
# Printing df3.head()
#                   ride_id  rideable_type           started_at  \
# 0        55262E4365A955A2   classic_bike  2022-01-18 08:23:52
# 1        D272F1B15D841EC0   classic_bike  2022-01-21 09:03:22
# 2        D1FCEF55EB4A807F   classic_bike  2022-01-22 14:28:32
# 3        E9CBDC6A0162C068  electric_bike  2022-01-19 14:49:47
# 4        2177A5B57326CE9B  electric_bike  2022-01-16 14:36:06
# ...                   ...            ...                  ...
# 6499184  5EBE9D296B9D3E3C   classic_bike  2022-04-22 13:08:15
# 6499185  B66382DEDA84C464   classic_bike  2022-04-13 17:10:49
# 6499186  9EC4C49BE4CB1A09   classic_bike  2022-04-12 15:58:47
# ...

# %%
import pandas as pd
import glob
import os

# setting the path for joining multiple files
# files = os.path.join("C:\\Users\\amit_\\Desktop\\", "sales*.csv")
# files = os.path.join("C:\\Users\\BZ Northwestern BC\\Class\\Tableau-Challenge\\", "20211*.csv") 
files = os.path.join("C:\\Users\\BZ Northwestern BC\\Class\\Tableau-Challenge\\Key_3_Month_citibike-tripdata\\", "*citibike-tripdata*.csv") 


# list of merged files returned
files = glob.glob(files)

print("Resultant CSV after joining all CSV files at a particular location...");

# joining files with concat and read_csv
df4 = pd.concat(map(pd.read_csv, files), ignore_index=True)
print("Did Concat")
df4.to_csv('out4.csv',index=False)
print("Printing df4.head()");
df4
# Out:
# Resultant CSV after joining all CSV files at a particular location...
# C:\Users\BZ Northwestern BC\anaconda3\lib\site-packages\pandas\core\reshape\concat.py:294: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   op = _Concatenator(
# Did Concat
# Printing df4.head()
#                   ride_id  rideable_type           started_at  \
# 0        55262E4365A955A2   classic_bike  2022-01-18 08:23:52
# 1        D272F1B15D841EC0   classic_bike  2022-01-21 09:03:22
# 2        D1FCEF55EB4A807F   classic_bike  2022-01-22 14:28:32
# 3        E9CBDC6A0162C068  electric_bike  2022-01-19 14:49:47
# 4        2177A5B57326CE9B  electric_bike  2022-01-16 14:36:06
# ...                   ...            ...                  ...
# 4179571  79E49EA8727CA662   classic_bike  2022-03-30 21:12:45
# 4179572  9C4F6A095779AAE2  electric_bike  2022-03-21 09:33:21
# 4179573  C1966A89B5078124  electric_bike  2022-03-04 14:31:36
# ...

# %%
import pandas as pd
import glob
import os

# setting the path for joining multiple files
# files = os.path.join("C:\\Users\\amit_\\Desktop\\", "sales*.csv")
# files = os.path.join("C:\\Users\\BZ Northwestern BC\\Class\\Tableau-Challenge\\", "20211*.csv") 
files = os.path.join("C:\\Users\\BZ Northwestern BC\\Class\\Tableau-Challenge\\Key_3_Month_citibike-tripdata\\", "*citibike-tripdata*.csv") 


# list of merged files returned
files = glob.glob(files)

print("Resultant CSV after joining all CSV files at a particular location...");

# joining files with concat and read_csv
df4 = pd.concat(map(pd.read_csv, files), ignore_index=True)
print("Did Concat")
df4.to_csv('out4.csv',index=False)
print("Printing df4.head()");
df4
